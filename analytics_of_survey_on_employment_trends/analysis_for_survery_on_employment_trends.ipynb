# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mns
from IPython.display import Markdown
plt.style.use("seaborn-whitegrid")
sns.set_style("whitegrid")
# %matplotlib inline

# %%
employment_df = pd.read_csv("../Datasets/survey_on_employment_trends.csv")
employment_df.head(5)
# Out:
#                          Timestamp             Name Age group  Gender  \
# 0  2023/01/11 10:15:18 AM GMT+5:30            Afsal     25-30   Other
# 1  2023/01/11 10:15:40 AM GMT+5:30    Vishnu vinod        <25    Male
# 2  2023/01/11 10:18:20 AM GMT+5:30       Vishal T S       <25    Male
# 3  2023/01/11 10:19:19 AM GMT+5:30  mohammad aslam        <25    Male
# 4  2023/01/11 10:26:10 AM GMT+5:30             Ammu       <25  Female
#
#             Where are you from? Marital status Work experience  \
# 0                         Tirur          Other         Fresher
# 1                       Kannur          Single        1-2years
# 2  Siddapur, Kodagu, Karnataka          Single        1-2years
# 3                      Thrissur         Single        1-2years
# 4                   Malappuram          Single         Fresher
#
#   Educational Qualification  Are you still studying?  \
# 0                      Btech                     Yes
# 1                   Diploma                       No
# ...

# %%
employment_df.shape
# Out:
# (95, 26)

# %%
## drop last column cause of unvalueable data

employment_df = employment_df.iloc[:,:-1]

# %%
employment_df.shape
# Out:
# (95, 25)

# %%
employment_df.columns.to_list()
# Out:
# ['Timestamp',
#  'Name',
#  'Age group',
#  'Gender',
#  'Where are you from?',
#  'Marital status',
#  'Work experience',
#  'Educational Qualification ',
#  'Are you still studying?',
#  'Do you believe degree is a must for job?',
#  'Interested area of work',
#  'Currently employed',
#  'Did you have a career break?',
#  'Did you switch your career?',
#  'Reason for shift in career?',
#  'Are you actively applying for job?',
#  'Skills that you are confident ',
#  'Job preference ',
#  'Have you carried out any independent works or projects?',
#  'Where do you search for Job?',
#  'Are you receiving response from recruiter after applying?',
#  'Are you interested in Freelancing?',
#  'Dream company type?',
#  'Preference of work ',
#  'What are the problems faced while job search?']

# %%
employment_df.columns = ["timestamp","name","age_group","gender","from","m_status","experience","education","is_studying","believe_degree_is_needed","interested_field","currently_employed","career_break","switch_cateer","reason_shift_career","actively_applying","confident_in_skills","job_preference","have_works_or_projects","place_search_job","receipt_response","interested_in_freelance","dream_company_type","onsite_or_remote","problems_for_search_job"]

# %%
employment_df.columns.to_list()
# Out:
# ['timestamp',
#  'name',
#  'age_group',
#  'gender',
#  'from',
#  'm_status',
#  'experience',
#  'education',
#  'is_studying',
#  'believe_degree_is_needed',
#  'interested_field',
#  'currently_employed',
#  'career_break',
#  'switch_cateer',
#  'reason_shift_career',
#  'actively_applying',
#  'confident_in_skills',
#  'job_preference',
#  'have_works_or_projects',
#  'place_search_job',
#  'receipt_response',
#  'interested_in_freelance',
#  'dream_company_type',
#  'onsite_or_remote',
#  'problems_for_search_job']
